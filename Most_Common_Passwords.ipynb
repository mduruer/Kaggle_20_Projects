# %% [markdown]
# # 10000 Common Passwords

# %% [markdown]
# <img src='most-used-passwords.jpg'>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings("ignore")
import seaborn as sns

# %%
df = pd.read_csv("common_passwords.csv")

# %%
df.head()
# Out:
#     password  length  num_chars  num_digits  num_upper  num_lower  \
# 0     123456       6          0           6          0          0
# 1   password       8          8           0          0          8
# 2   12345678       8          0           8          0          0
# 3     qwerty       6          6           0          0          6
# 4  123456789       9          0           9          0          0
#
#    num_special  num_vowels  num_syllables
# 0            0           0              1
# 1            0           2              2
# 2            0           0              1
# 3            0           1              3
# 4            0           0              1

# %%
df.corr()
# Out:
#                  length  num_chars  num_digits  num_upper  num_lower  \
# length         1.000000   0.116878    0.351297   0.019704   0.114379
# num_chars      0.116878   1.000000   -0.887925   0.040131   0.993385
# num_digits     0.351297  -0.887925    1.000000  -0.028685  -0.882850
# num_upper      0.019704   0.040131   -0.028685   1.000000  -0.074875
# num_lower      0.114379   0.993385   -0.882850  -0.074875   1.000000
# num_special   -0.006777  -0.041931   -0.003927  -0.002221  -0.041592
# num_vowels     0.057904   0.803500   -0.729944  -0.055813   0.808304
# num_syllables  0.234272   0.590230   -0.446826   0.012514   0.587610
#
#                num_special  num_vowels  num_syllables
# length           -0.006777    0.057904       0.234272
# num_chars        -0.041931    0.803500       0.590230
# num_digits       -0.003927   -0.729944      -0.446826
# num_upper        -0.002221   -0.055813       0.012514
# num_lower        -0.041592    0.808304       0.587610
# num_special       1.000000   -0.036505      -0.049706
# num_vowels       -0.036505    1.000000       0.506504
# num_syllables    -0.049706    0.506504       1.000000

# %%
##ax = plt.subplots(figsize = (10,10))
sns.heatmap(df.corr(),annot = True);

# %%
df.head(10)['password'].reset_index().rename(columns = {"index" : "Rank", "password" : "Password"})
# Out:
#    Rank   Password
# 0     0     123456
# 1     1   password
# 2     2   12345678
# 3     3     qwerty
# 4     4  123456789
# 5     5      12345
# 6     6       1234
# 7     7     111111
# 8     8    1234567
# 9     9     dragon

# %%
df.password.value_counts().sort_values(ascending=False).head(50)
# Out:
# abcdef           2
# easy             2
# password         1
# 111111           1
# master           1
# shadow           1
# 12345678         1
# qwerty           1
# 123456789        1
# 12345            1
# 1234             1
# 1234567          1
# qwertyuiop       1
# dragon           1
# 123123           1
# wrongpassword    1
# abc123           1
# football         1
# monkey           1
# letmein          1
# 666666           1
# jordan           1
# genesis          1
# pussy            1
# boomer           1
# 1qaz2wsx         1
# 123321           1
# mustang          1
# 1234567890       1
# michael          1
# 654321           1
# superman         1
# trustno1         1
# 7777777          1
# zxcvbnm          1
# 121212           1
# 000000           1
# qazwsx           1
# 123qwe           1
# killer           1
# 696969           1
# jennifer         1
# asdfgh           1
# tigger           1
# starwars         1
# daniel           1
# buster           1
# soccer           1
# harley           1
# batman           1
# Name: password, dtype: int64

# %% [raw]
# Some of the lengthy Passwords:

# %%
df.sort_values("length", ascending = False)['password'].head(10).reset_index().rename(columns = {"index" : "Rank", "password" : "Password"})
# Out:
#    Rank          Password
# 0  4761  PolniyPizdec0211
# 1  2201   Mailcreated5240
# 2  3338     Sojdlg123aljg
# 3    11     wrongpassword
# 4  2609      123456qwerty
# 5  8968      123456789qwe
# 6  9364      masterbating
# 7  1239      123qweasdzxc
# 8  1664      q1w2e3r4t5y6
# 9  6511      ghjcnjgfhjkm

# %% [raw]
# Some of the most common short passwords:

# %%
df.sort_values("length", ascending = True)['password'].head(10).reset_index().rename(columns = {"index" : "Rank", "password" : "Password"})
# Out:
#    Rank Password
# 0  4349      sex
# 1  8186      mad
# 2  1591      123
# 3  5214     shao
# 4   718     1980
# 5  8025     hung
# 6  6134     beta
# 7  8020     junk
# 8  4760     qiao
# 9  6146     1949

# %% [raw]
# some of the most common passwords with more number of sounds : absurd passwords

# %%
df.sort_values("num_syllables", ascending = False)['password'].head(10).reset_index().rename(columns = {"index" : "Rank", "password" : "Password"})
# Out:
#    Rank      Password
# 0  6047      cccccccc
# 1  5303      llllllll
# 2  3973      mmmmmmmm
# 3  5678      hhhhhhhh
# 4  7058       mmmmmmm
# 5  3746    fktrcfylhf
# 6  8152  sonyericsson
# 7  9911  qwerasdfzxcv
# 8  4652    rjycnfynby
# 9  4297  qwertyqwerty

# %%
df.sort_values("num_special", ascending = False)['password'].head(10).reset_index().rename(columns = {"index" : "Rank", "password" : "Password"})
# Out:
#    Rank     Password
# 0  5478       ??????
# 1  7020       ******
# 2  8332        ?????
# 3  4745        *****
# 4  3332    0.0.0.000
# 5  2154      0.0.000
# 6  4517         f**k
# 7  6896       w_pass
# 8  6775    sasha_007
# 9  2537  fuck_inside
