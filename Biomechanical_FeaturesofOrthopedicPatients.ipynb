# %% [markdown]
# # Biomechanical features of orthopedic patients

# %% [raw]
# column_3C_weka.csv (file with three class labels)
#
# The first task consists in classifying patients as belonging to one out of three categories: Normal (100 patients), Disk Hernia (60 patients) or Spondylolisthesis (150 patients).
# column_2C_weka.csv (file with two class labels)
#
# For the second task, the categories Disk Hernia and Spondylolisthesis were merged into a single category labelled as 'abnormal'. Thus, the second task consists in classifying patients as belonging to one out of two categories: Normal (100 patients) or Abnormal (210 patients).

# %% [markdown]
# <img src='dataset-cover.jpg'>

# %%
import pandas as pd

# %%
df = pd.read_csv('column_2C_weka.csv')

# %%
df.head()
# Out:
#    pelvic_incidence  pelvic_tilt numeric  lumbar_lordosis_angle  sacral_slope  \
# 0         63.027817            22.552586              39.609117     40.475232
# 1         39.056951            10.060991              25.015378     28.995960
# 2         68.832021            22.218482              50.092194     46.613539
# 3         69.297008            24.652878              44.311238     44.644130
# 4         49.712859             9.652075              28.317406     40.060784
#
#    pelvic_radius  degree_spondylolisthesis     class
# 0      98.672917                 -0.254400  Abnormal
# 1     114.405425                  4.564259  Abnormal
# 2     105.985135                 -3.530317  Abnormal
# 3     101.868495                 11.211523  Abnormal
# 4     108.168725                  7.918501  Abnormal

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 310 entries, 0 to 309
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   pelvic_incidence          310 non-null    float64
#  1   pelvic_tilt numeric       310 non-null    float64
#  2   lumbar_lordosis_angle     310 non-null    float64
#  3   sacral_slope              310 non-null    float64
#  4   pelvic_radius             310 non-null    float64
#  5   degree_spondylolisthesis  310 non-null    float64
#  6   class                     310 non-null    object
# dtypes: float64(6), object(1)
# memory usage: 17.1+ KB

# %%
df['class'] = df['class'].map({'Abnormal':1,
                             'Normal':0},
                             na_action=None)

# %%
 X = df.drop(columns='class')

# %%
y = df['class']
y = df['class'].map({'Abnormal':1,
                             'Normal':0},
                             na_action=None)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=1)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.ensemble import GradientBoostingClassifier
gbc = GradientBoostingClassifier()
from sklearn.ensemble import RandomForestClassifier
r= RandomForestClassifier()
from sklearn.tree import DecisionTreeClassifier
d= DecisionTreeClassifier()
from sklearn.linear_model import LogisticRegression
log = LogisticRegression()
from sklearn.neighbors import KNeighborsClassifier
k = KNeighborsClassifier()
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import BernoulliNB

g = GaussianNB()
b = BernoulliNB();

# %%
algorithms = [g,b,k,log,gbc,r,d]
names = ['GaussianNB','BernoulliNB', 'K Nearest', 'Logistic','GradientBoosting','RandomForest','DecisionTree',]
def algo_test(A, b, algorithms = algorithms,names = names):
    # fit the data
    for i in range(len(algorithms)):
        algorithms[i] = algorithms[i].fit(A, b)
    
    accuracy = []
    precision = []
    recall = []
    f1 = []
    for i in range(len(algorithms)):
        accuracy.append(accuracy_score(y, algorithms[i].predict(X)))
        precision.append(precision_score(y, algorithms[i].predict(X)))
        recall.append(recall_score(y,algorithms[i].predict(X)))
        f1.append(f1_score(y, algorithms[i].predict(X)))
    metrics = pd.DataFrame(columns = ['Accuracy', 'Precision', 'Recall', 'F1'], index = names)
    metrics['Accuracy'] = accuracy
    metrics['Precision'] = precision
    metrics['Recall'] = recall
    metrics['F1'] = f1
    return metrics.sort_values('F1', ascending = False)

# %%
algo_test(X_test, y_test)
# Out:
#                   Accuracy  Precision    Recall        F1
# Logistic          0.867742   0.904306  0.900000  0.902148
# DecisionTree      0.841935   0.870968  0.900000  0.885246
# RandomForest      0.841935   0.877934  0.890476  0.884161
# GradientBoosting  0.841935   0.881517  0.885714  0.883610
# K Nearest         0.838710   0.892157  0.866667  0.879227
# BernoulliNB       0.735484   0.758065  0.895238  0.820961
# GaussianNB        0.770968   0.888268  0.757143  0.817481

# %% [markdown]
# # PyCaret Classification Tahminleme Yapalım

# %%
from pycaret.classification import*

# %%
##Modelimizi Compile Ediyoruz
exp_name=setup(df,target='class')
# Out:
# <style type="text/css">
# #T_be200_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_be200">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_be200_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_be200_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_be200_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_be200_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_be200_row0_col1" class="data row0 col1" >4619</td>
#     </tr>
#     <tr>
#       <th id="T_be200_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_be200_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_be200_row1_col1" class="data row1 col1" >class</td>
#     </tr>
#     <tr>
#       <th id="T_be200_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_be200_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_be200_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_be200_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_be200_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_be200_row3_col1" class="data row3 col1" >(310, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_be200_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_be200_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_be200_row4_col1" class="data row4 col1" >(310, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_be200_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_be200_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_be200_row5_col1" class="data row5 col1" >(217, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_be200_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_be200_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_be200_row6_col1" class="data row6 col1" >(93, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_be200_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_be200_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_be200_row7_col1" class="data row7 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_be200_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_be200_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_be200_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_be200_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_be200_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_be200_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_be200_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_be200_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_be200_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_be200_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_be200_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_be200_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_be200_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_be200_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_be200_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_be200_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_be200_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_be200_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_be200_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_be200_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_be200_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_be200_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_be200_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_be200_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_be200_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_be200_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_be200_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_be200_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_be200_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_be200_row17_col1" class="data row17 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_be200_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_be200_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_be200_row18_col1" class="data row18 col1" >8360</td>
#     </tr>
#   </tbody>
# </table>

# %%
best_model=compare_models()
# Out:
# <style type="text/css">
# #T_865b4 th {
#   text-align: left;
# }
# #T_865b4_row0_col0, #T_865b4_row0_col2, #T_865b4_row0_col3, #T_865b4_row0_col4, #T_865b4_row1_col0, #T_865b4_row1_col1, #T_865b4_row1_col3, #T_865b4_row1_col4, #T_865b4_row1_col5, #T_865b4_row1_col6, #T_865b4_row1_col7, #T_865b4_row2_col0, #T_865b4_row2_col1, #T_865b4_row2_col2, #T_865b4_row2_col3, #T_865b4_row2_col4, #T_865b4_row2_col5, #T_865b4_row2_col6, #T_865b4_row2_col7, #T_865b4_row3_col0, #T_865b4_row3_col1, #T_865b4_row3_col2, #T_865b4_row3_col3, #T_865b4_row3_col4, #T_865b4_row3_col5, #T_865b4_row3_col6, #T_865b4_row3_col7, #T_865b4_row4_col0, #T_865b4_row4_col1, #T_865b4_row4_col2, #T_865b4_row4_col3, #T_865b4_row4_col4, #T_865b4_row4_col5, #T_865b4_row4_col6, #T_865b4_row4_col7, #T_865b4_row5_col0, #T_865b4_row5_col1, #T_865b4_row5_col2, #T_865b4_row5_col3, #T_865b4_row5_col4, #T_865b4_row5_col5, #T_865b4_row5_col6, #T_865b4_row5_col7, #T_865b4_row6_col0, #T_865b4_row6_col1, #T_865b4_row6_col2, #T_865b4_row6_col3, #T_865b4_row6_col4, #T_865b4_row6_col5, #T_865b4_row6_col6, #T_865b4_row6_col7, #T_865b4_row7_col0, #T_865b4_row7_col1, #T_865b4_row7_col2, #T_865b4_row7_col3, #T_865b4_row7_col4, #T_865b4_row7_col5, #T_865b4_row7_col6, #T_865b4_row7_col7, #T_865b4_row8_col0, #T_865b4_row8_col1, #T_865b4_row8_col2, #T_865b4_row8_col3, #T_865b4_row8_col4, #T_865b4_row8_col5, #T_865b4_row8_col6, #T_865b4_row8_col7, #T_865b4_row9_col0, #T_865b4_row9_col1, #T_865b4_row9_col2, #T_865b4_row9_col3, #T_865b4_row9_col4, #T_865b4_row9_col5, #T_865b4_row9_col6, #T_865b4_row9_col7, #T_865b4_row10_col0, #T_865b4_row10_col1, #T_865b4_row10_col2, #T_865b4_row10_col3, #T_865b4_row10_col4, #T_865b4_row10_col5, #T_865b4_row10_col6, #T_865b4_row10_col7, #T_865b4_row11_col0, #T_865b4_row11_col1, #T_865b4_row11_col2, #T_865b4_row11_col3, #T_865b4_row11_col5, #T_865b4_row11_col6, #T_865b4_row11_col7, #T_865b4_row12_col0, #T_865b4_row12_col1, #T_865b4_row12_col2, #T_865b4_row12_col3, #T_865b4_row12_col4, #T_865b4_row12_col5, #T_865b4_row12_col6, #T_865b4_row12_col7, #T_865b4_row13_col0, #T_865b4_row13_col1, #T_865b4_row13_col2, #T_865b4_row13_col3, #T_865b4_row13_col4, #T_865b4_row13_col5, #T_865b4_row13_col6, #T_865b4_row13_col7, #T_865b4_row14_col0, #T_865b4_row14_col1, #T_865b4_row14_col2, #T_865b4_row14_col4, #T_865b4_row14_col5, #T_865b4_row14_col6, #T_865b4_row14_col7 {
#   text-align: left;
# }
# #T_865b4_row0_col1, #T_865b4_row0_col5, #T_865b4_row0_col6, #T_865b4_row0_col7, #T_865b4_row1_col2, #T_865b4_row11_col4, #T_865b4_row14_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_865b4_row0_col8, #T_865b4_row1_col8, #T_865b4_row2_col8, #T_865b4_row3_col8, #T_865b4_row4_col8, #T_865b4_row5_col8, #T_865b4_row6_col8, #T_865b4_row7_col8, #T_865b4_row9_col8, #T_865b4_row10_col8, #T_865b4_row11_col8, #T_865b4_row12_col8, #T_865b4_row13_col8, #T_865b4_row14_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_865b4_row8_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_865b4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_865b4_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_865b4_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_865b4_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_865b4_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_865b4_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_865b4_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_865b4_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_865b4_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_865b4_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_865b4_level0_row0" class="row_heading level0 row0" >rf</th>
#       <td id="T_865b4_row0_col0" class="data row0 col0" >Random Forest Classifier</td>
#       <td id="T_865b4_row0_col1" class="data row0 col1" >0.8580</td>
#       <td id="T_865b4_row0_col2" class="data row0 col2" >0.9241</td>
#       <td id="T_865b4_row0_col3" class="data row0 col3" >0.8986</td>
#       <td id="T_865b4_row0_col4" class="data row0 col4" >0.8991</td>
#       <td id="T_865b4_row0_col5" class="data row0 col5" >0.8953</td>
#       <td id="T_865b4_row0_col6" class="data row0 col6" >0.6707</td>
#       <td id="T_865b4_row0_col7" class="data row0 col7" >0.6857</td>
#       <td id="T_865b4_row0_col8" class="data row0 col8" >0.1160</td>
#     </tr>
#     <tr>
#       <th id="T_865b4_level0_row1" class="row_heading level0 row1" >lightgbm</th>
#       <td id="T_865b4_row1_col0" class="data row1 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_865b4_row1_col1" class="data row1 col1" >0.8442</td>
#       <td id="T_865b4_row1_col2" class="data row1 col2" >0.9289</td>
#       <td id="T_865b4_row1_col3" class="data row1 col3" >0.8848</td>
#       <td id="T_865b4_row1_col4" class="data row1 col4" >0.8904</td>
#       <td id="T_865b4_row1_col5" class="data row1 col5" >0.8856</td>
#       <td id="T_865b4_row1_col6" class="data row1 col6" >0.6387</td>
#       <td id="T_865b4_row1_col7" class="data row1 col7" >0.6458</td>
#       <td id="T_865b4_row1_col8" class="data row1 col8" >0.1320</td>
#     </tr>
#     <tr>
#       <th id="T_865b4_level0_row2" class="row_heading level0 row2" >gbc</th>
#       <td id="T_865b4_row2_col0" class="data row2 col0" >Gradient Boosting Classifier</td>
#       <td id="T_865b4_row2_col1" class="data row2 col1" >0.8439</td>
#       <td id="T_865b4_row2_col2" class="data row2 col2" >0.9180</td>
#       <td id="T_865b4_row2_col3" class="data row2 col3" >0.8781</td>
#       <td id="T_865b4_row2_col4" class="data row2 col4" >0.8973</td>
#       <td id="T_865b4_row2_col5" class="data row2 col5" >0.8853</td>
#       <td id="T_865b4_row2_col6" class="data row2 col6" >0.6380</td>
#       <td id="T_865b4_row2_col7" class="data row2 col7" >0.6447</td>
#       <td id="T_865b4_row2_col8" class="data row2 col8" >0.0920</td>
#     </tr>
#     <tr>
#       <th id="T_865b4_level0_row3" class="row_heading level0 row3" >xgboost</th>
#       <td id="T_865b4_row3_col0" class="data row3 col0" >Extreme Gradient Boosting</td>
#       <td id="T_865b4_row3_col1" class="data row3 col1" >0.8400</td>
#       <td id="T_865b4_row3_col2" class="data row3 col2" >0.9269</td>
#       <td id="T_865b4_row3_col3" class="data row3 col3" >0.8857</td>
#       <td id="T_865b4_row3_col4" class="data row3 col4" >0.8835</td>
#       <td id="T_865b4_row3_col5" class="data row3 col5" >0.8824</td>
#       <td id="T_865b4_row3_col6" class="data row3 col6" >0.6296</td>
#       <td id="T_865b4_row3_col7" class="data row3 col7" >0.6402</td>
#       <td id="T_865b4_row3_col8" class="data row3 col8" >0.0420</td>
#     </tr>
#     <tr>
#       <th id="T_865b4_level0_row4" class="row_heading level0 row4" >lr</th>
#       <td id="T_865b4_row4_col0" class="data row4 col0" >Logistic Regression</td>
#       <td id="T_865b4_row4_col1" class="data row4 col1" >0.8348</td>
#       <td id="T_865b4_row4_col2" class="data row4 col2" >0.9251</td>
#       <td id="T_865b4_row4_col3" class="data row4 col3" >0.8648</td>
#       <td id="T_865b4_row4_col4" class="data row4 col4" >0.8912</td>
#       <td id="T_865b4_row4_col5" class="data row4 col5" >0.8771</td>
#       <td id="T_865b4_row4_col6" class="data row4 col6" >0.6248</td>
#       <td id="T_865b4_row4_col7" class="data row4 col7" >0.6276</td>
#       <td id="T_865b4_row4_col8" class="data row4 col8" >0.3020</td>
#     </tr>
#     <tr>
#       <th id="T_865b4_level0_row5" class="row_heading level0 row5" >et</th>
#       <td id="T_865b4_row5_col0" class="data row5 col0" >Extra Trees Classifier</td>
#       <td id="T_865b4_row5_col1" class="data row5 col1" >0.8346</td>
#       <td id="T_865b4_row5_col2" class="data row5 col2" >0.9111</td>
#       <td id="T_865b4_row5_col3" class="data row5 col3" >0.8919</td>
#       <td id="T_865b4_row5_col4" class="data row5 col4" >0.8749</td>
#       <td id="T
# Processing:   0%|          | 0/65 [00:00<?, ?it/s]
